# %% [markdown]
# # **Informe Final del Proyecto**
#
#
#
#
# ##
#
#
#
#
#
#
# ## **Índice**
#
# 1. **Portada**
# 3. **Introducción**
#     - ¿Qué problema se quiere solucionar?
#     - ¿Cómo se puede aportar?
#     - Objetivo General
#     - Objetivos Específicos
#     - Alcance del Proyecto
# 4. **Objetivos**
#     - Objetivo general
#     - Objetivos especificos
#     - Alcance del proyecto
# 5. **Planeamieno de Extracción de Datos**
#     - Fuentes de Información
#       - IQAir API
#       - WeatherAPI
# 6. **Metodologia**
#     - Planificacion y seleccion de fuentes de datos
#     - Extraccion de datos
#     - Procesamiento de los datos extraidos
#     - Organizacion y manejo de datos
#     - Validacion y organizacion de los datos
#     - Visualizacion de resultados
# 7. **Herramientas utilizadas**
#     - Lenguajes de programacion
#       - Python
#     - Librerias
#     - Entorno de desarrollo
#     - Control de versiones
# 8. **Configuracion incicial y extraccion de datos**
#     - Ciudades con mejor calidad del aire (AQI más bajo)
#     - Ciudades con condiciones climáticas más favorables
#     - Relación entre clima y calidad del aire
# 9. **Conclusiones y Recomendaciones**
#     - Conclusión Principal:
#       - Ciudades más adecuadas para la salud respiratoria
#     - Recomendaciones:
#       - Sugerencias para habitantes y viajeros
#       - Propuestas para autoridades locales
# 10. **Integración de Códigos y Repositorio GitHub**
#     - Documentación del código
#     - Estructura del repositorio
#     - URL del Repositorio GitHub
# 11. **Anexos**
#     - Tablas y gráficos adicionales
#     - Ejemplos de salida de datos
#     - Referencias a las APIs y herramientas utilizadas
#
# ---
#
# ## **Evaluación de la Calidad del Aire y las Condiciones Climáticas en el Perú**
#
#
# ---
# ## **Introduccion**
# Este informe presenta un análisis comparativo entre calidad del aire y las condiciones climáticas en diversas ciudades del Perú, utilizando datos extraídos en tiempo real de las APIs **IQAir** y **WeatherAPI**.
#
# Este proyecto tuvo como objetivo identificar las ciudades más adecuadas para la salud respiratoria a partir de parámetros como el Índice de Calidad del Aire (AQI), temperatura y humedad. Se implementaron técnicas de procesamiento de datos, análisis y visualizaciones efectivas para facilitar la interpretación de los resultados.
#
# ---
# ## **1. Objetivos**
#
# ### **Objetivo General**
# Evaluar las condiciones climáticas y la calidad del aire en distintas ciudades del Perú para identificar las zonas más adecuadas para vivir, priorizando la salud respiratoria.
#
# ### **Objetivos Específicos**
# - Extraer datos sobre la calidad del aire (AQI) y condiciones climáticas (temperatura, humedad y viento) mediante APIs confiables y de acceso público.
# - Analizar y comparar los datos obtenidos para identificar patrones relevantes y correlaciones entre calidad del aire y condiciones climáticas.
# - Clasificar las ciudades en función de los riesgos asociados a la calidad del aire para salud respiratoria, para poder escoger una la mejor opcion
#   entre todas las ciudades para vivir.
# - Proporcionar recomendaciones basadas en los datos obtenidos para la mejora de la calidad de vida en las ciudades con condiciones menos favorables.
# - Generar visualizaciones efectivas que permitan interpretar de manera clara las condiciones ambientales en las ciudades seleccionadas.
#
# ### **Alcance del Proyecto**
# El análisis se enfoca en 5 a 10 ciudades seleccionadas del Perú, comparando parámetros climáticos y de calidad del aire a partir de datos en tiempo real.
#
#
# ## **2. Planeamiento de Extracción de Datos**
#
# ### **Fuentes de Información**
# Para el análisis, se seleccionaron APIs confiables que ofrecen datos actualizados y detallados:
#
# 1. **IQAir API** : Esta API ofrece información detallada sobre la calidad en todo el mundo, incluyendo el indice de calidad de aire (AQI) y la concentración dee (AQI) y contaminantes en diferentes ubicac Perú.
#    - Información proporcionada: Índice de Calidad del Aire (AQI), niveles de contaminantes como PM2.5, PM10 y gases como dióxido de carbono y ozono.
#    - Utilidad: Permite identificar la calidad del aire en cada ciudad y clasificarla según estándares internacionales.
#
# Fuente: https://www.iqair.com/es/air-quality-monitors/api?srsltid=AfmBOoq7UNkbd9dFn5TGnWW5LNf-ftVERigvxPD1RDTqNjZfVQNlARls
#
# 2. **WeatherAPI**: Se puede obtener datos metereologicos y orciona datos actualizados sobre condiciones climáticas, como temperatura, humedad, viento y previsión  Su versatilidad la hace una herramienta muy importante para poder analizar las condiciones climaticas y como estas pueden influir en la calidad del aire.meteorológica.
#    - Información proporcionada: Temperatura, humedad, velocidad del viento y condiciones climáticas generales.
#    - Utilidad: Complementa el análisis del AQI con datos sobre las condiciones meteorológicas.
#
# Fuente: https://www.xweather.com/weather-api?gad_source=1&gclid=CjwKCAiAgoq7BhBxEiwAVcW0LMuEtDeFWJgT498ZmiK6D7uawguRNlOvfRED8RU-hbvluZeKhCdrbRoCclgQAvD_BwE
#
#
#
# ## **3. Metodología**
#
# 1. **Planificación y Selección de Fuentes de Datos**
#    - Las APIs fueron seleccionadas por su disponibilidad, fiabilidad y alcance geográfico, permitiendo obtener información actualizada de las ciudades peruanas.
#    - Se revisaron las instrucciones de uso de cada API para entender cómo usarlas correctamente, y se procedio a acceder a los datos que fueron necesarios para lograr los objetivos.
#
# 2. **Extracción de Datos**
#    - Se configuraron dos funciones específicas en Python para interactuar con cada API:
#      - `obtener_clima_weatherapi`: Recupera datos climáticos de WeatherAPI.
#      - `obtener_calidad_aire_iqair`: Recupera datos de calidad del aire de IQAir.
#
#
# 3. **Procesamiento de los Datos Extraídos**
#    - Los datos se procesan extrayendo información relevante de las APIs seleccionadas: WeatherAPI y IQAir.
#
#          -Temperatura (°C) y humedad (%) desde WeatherAPI.
#          -Índice de Calidad del Aire (AQI) desde IQAir, utilizando la latitud y longitud obtenida previamente.
#
#    - Los datos fueron descargados desde las APIs en formato JSON y luego transformados en listas especificas para cada variable (temperatura, humedad y AQI).
#
#
# 5. **Organización y Manejo de Datos**
#    - Los datos de las dos APIs se almacenaron en listas separadas para cada variable. Esta organizacion permitio manejar los datos de manera eficiente para su analisis y visualizacion sin necesidad de transformaciones intermedias.
#
# 6. **Validación y Organización de los Datos**
#    - Se implementaron verificaciones para manejar posibles errores en la respuesta de las APis, como datos faltantes o respustas invalidas.
#    - Cuando una API no devuelve datos validos, se asignan valores predeterminados (0) para garantizar la continuidad del analisis.
#
# 7. **Visualización de Resultados**
#    - Se diseñaron gráficos comparativos utilizando **Matplotlib** para mostrar las diferencias de temperatura, humedad y calidad del aire entre las ciudades seleccionadas.
#
# ---
#
# ### **Herramientas Utilizadas**
#
# 1. **Lenguaje de Programación**
#    - Python fue seleccionado por su versatilidad y disponibilidad de librerías especializadas para la manipulación de datos y visualización.
#
# 2. **Librerías**
#    - `requests`: Para realizar solicitudes HTTP y obtener datos de las APIs.
#    - `pandas`: Para estructurar, limpiar y analizar los datos.
#    - `matplotlib`: Para generar visualizaciones claras y efectivas.
#
# 3. **Entorno de Desarrollo**
#    - **Jupyter Notebook**: Utilizado para la implementación, depuración y documentación del código.
#
# 4. **Control de Versiones**
#    - **GitHub**: Para almacenar y compartir el código fuente, asegurando la colaboración efectiva entre los integrantes del proyecto.
#
# ---
#
#
#
# ## **4. Configuración Inicial y Extracción de Datos**

# %% [markdown]
# ## **5. Producto final: Analisis**
# 1. Análisis Comparativo: En el analisis se incluye
#    - Clasificación de las ciudades según su AQI y categorías de riesgo
#      - 0-50: Buena
#      - 51-100: Moderada
#      - 101-150: Insalubre para grupos sensibles
#      - 150: Insalubre

# %% [markdown]
# ## **6. Conclusiones y recomendaciones**
# ### Conclusiones
#     - Cusco y Arequipa tienen los valores más bajos de AQI, clasificándose como ciudades adecuadas para la salud respiratoria.
#     - Lima y Trujillo presentan niveles de AQI moderados o insalubres, con mayor necesidad de monitoreo y acción.
#
# ### Recomendaciones
# **   - Sugerencias para habitantes y viajeros.
#    - Propuestas para autoridades locales.  **

# %% [markdown]
# ## **8. Anexos**

# %%
# **Índice**

1. [Introducción](#introducción)  
2. [Objetivos](#objetivos)  
   2.1 [Objetivo General](#objetivo-general)  
   2.2 [Objetivos Específicos](#objetivos-específicos)  
   2.3 [Alcance del Proyecto](#alcance-del-proyecto)  
3. [Planeamiento de Extracción de Datos](#planeamiento-de-extracción-de-datos)  
   3.1 [Fuentes de Información](#fuentes-de-información)  
4. [Metodología](#metodología)  
   4.1 [Planificación y Selección de Fuentes de Datos](#planificación-y-selección-de-fuentes-de-datos)  
   4.2 [Extracción de Datos](#extracción-de-datos)  
   4.3 [Procesamiento de los Datos Extraídos](#procesamiento-de-los-datos-extraídos)  
   4.4 [Organización y Manejo de Datos](#organización-y-manejo-de-datos)  
   4.5 [Validación y Organización de los Datos](#validación-y-organización-de-los-datos)  
   4.6 [Visualización de Resultados](#visualización-de-resultados)  
5. [Herramientas Utilizadas](#herramientas-utilizadas)  
   5.1 [Lenguaje de Programación](#lenguaje-de-programación)  
   5.2 [Librerías](#librerías)  
   5.3 [Entorno de Desarrollo](#entorno-de-desarrollo)  
   5.4 [Control de Versiones](#control-de-versiones)  
6. [Configuración Inicial y Extracción de Datos](#configuración-inicial-y-extracción-de-datos)
# Out:
#   Cell In[64], line 5
#     2.1 [Objetivo General](#objetivo-general)
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
